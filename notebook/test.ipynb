# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import dataset
fig = plt.figure(2, (8, 8))
x = np.arange(0, 1, 0.02)
y = []
for t in x:
    y_1 = dataset.function(t,0.5209)
    y.append(y_1)
plt.plot(x, y, label="f(x1,x2=0.5209)")
y_com = dataset.function(0.4522,0.5209)
plt.scatter(0.4522, y_com, marker="o", label="original sample", c="g")
plt.axhline(y=y_com, color='r', linestyle='-')
plt.axhline(y=2.365, color='b', linestyle='-')
plt.scatter(0.5067, 2.11427413, marker="o", label="proper virtual sample", c="#DC143C")
plt.scatter(0.5067, 2.34, marker="x", label="bad virtual sample b", c="k")
plt.axvline(x=0.5067,ls="-",c="b")

plt.xlabel("x1")
plt.ylabel("y")
plt.ylim(1.5, 3.5)
plt.legend()
plt.savefig(f"E:/毕业论文/中期/data.png")
plt.show()
